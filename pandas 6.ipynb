# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col = 'Respondent')
schema_df =pd.read_csv('survey_results_schema.csv', index_col = 'Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
ethiopia = df.groupby('Country').get_group('Ethiopia').reset_index(drop=True)

# %%
ethiopia
# Out:
#                                            MainBranch Hobbyist  \
# 0              I am a student who is learning to code      Yes
# 1                      I am a developer by profession      Yes
# 2                      I am a developer by profession      Yes
# 3                      I am a developer by profession      Yes
# 4                      I am a developer by profession      Yes
# 5                      I am a developer by profession       No
# 6                      I am a developer by profession      Yes
# 7                      I am a developer by profession      Yes
# 8              I am a student who is learning to code       No
# 9   I am not primarily a developer, but I write co...      Yes
# 10                     I am a developer by profession      Yes
# 11             I am a student who is learning to code      Yes
# 12  I am not primarily a developer, but I write co...      Yes
# 13                     I am a developer by profession      Yes
# 14                     I am a developer by profession      Yes
# 15                     I am a developer by profession      Yes
# 16                     I am a developer by profession      Yes
# 17                     I am a developer by profession      Yes
# 18                     I am a developer by profession       No
# 19                     I am a developer by profession      Yes
# 20             I am a student who is learning to code      Yes
# 21                     I am a developer by profession       No
# 22                     I am a developer by profession      Yes
# 23             I am a student who is learning to code      Yes
# 24                     I am a developer by profession      Yes
# 25             I am a student who is learning to code      Yes
# 26             I am a student who is learning to code      Yes
# 27                     I am a developer by profession      Yes
# 28             I am a student who is learning to code      Yes
# 29                     I am a developer by profession      Yes
# 30  I am not primarily a developer, but I write co...       No
# 31                     I am a developer by profession      Yes
# 32             I am a student who is learning to code      Yes
# 33                     I am a developer by profession      Yes
# 34                     I am a developer by profession       No
# 35  I am not primarily a developer, but I write co...      Yes
# 36  I used to be a developer by profession, but no...       No
# 37                     I am a developer by profession      Yes
# 38             I am a student who is learning to code      Yes
# 39                     I am a developer by profession      Yes
# 40                        I code primarily as a hobby      Yes
# 41                     I am a developer by profession       No
# 42             I am a student who is learning to code       No
# 43             I am a student who is learning to code      Yes
# 44                     I am a developer by profession      Yes
# 45                     I am a developer by profession       No
# 46                     I am a developer by profession      Yes
# 47                     I am a developer by profession      Yes
# 48                        I code primarily as a hobby      Yes
# 49                     I am a developer by profession      Yes
# 50                                                NaN      Yes
# 51                                                NaN       No
#
#                                           OpenSourcer  \
# 0                                               Never
# 1                          Once a month or more often
# 2                          Once a month or more often
# 3                                               Never
# 4                                               Never
# 5                             Less than once per year
# 6                                               Never
# 7                                               Never
# 8                          Once a month or more often
# 9                          Once a month or more often
# 10                         Once a month or more often
# 11                                              Never
# 12                                              Never
# 13                            Less than once per year
# 14  Less than once a month but more than once per ...
# 15                                              Never
# 16                            Less than once per year
# 17                         Once a month or more often
# 18                                              Never
# 19                                              Never
# 20                            Less than once per year
# 21                                              Never
# 22                                              Never
# 23                                              Never
# 24                            Less than once per year
# 25  Less than once a month but more than once per ...
# 26                            Less than once per year
# 27                            Less than once per year
# 28                                              Never
# 29  Less than once a month but more than once per ...
# 30  Less than once a month but more than once per ...
# 31                                              Never
# 32                         Once a month or more often
# 33                         Once a month or more often
# 34                                              Never
# 35  Less than once a month but more than once per ...
# 36                                              Never
# 37                                              Never
# 38                            Less than once per year
# 39  Less than once a month but more than once per ...
# 40                            Less than once per year
# 41  Less than once a month but more than once per ...
# 42                                              Never
# 43                                              Never
# 44                                              Never
# 45                                              Never
# 46                         Once a month or more often
# 47                            Less than once per year
# 48                            Less than once per year
# 49                            Less than once per year
# 50                                              Never
# 51                            Less than once per year
#
#                                            OpenSource  \
# 0   OSS is, on average, of HIGHER quality than pro...
# 1   OSS is, on average, of HIGHER quality than pro...
# 2   OSS is, on average, of HIGHER quality than pro...
# 3   OSS is, on average, of HIGHER quality than pro...
# 4   OSS is, on average, of HIGHER quality than pro...
# 5   The quality of OSS and closed source software ...
# 6   OSS is, on average, of HIGHER quality than pro...
# 7   The quality of OSS and closed source software ...
# 8   The quality of OSS and closed source software ...
# 9   OSS is, on average, of LOWER quality than prop...
# 10  OSS is, on average, of HIGHER quality than pro...
# 11  OSS is, on average, of LOWER quality than prop...
# 12  The quality of OSS and closed source software ...
# 13  OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
# 15  OSS is, on average, of HIGHER quality than pro...
# 16  The quality of OSS and closed source software ...
# 17  OSS is, on average, of LOWER quality than prop...
# 18  OSS is, on average, of HIGHER quality than pro...
# 19  OSS is, on average, of HIGHER quality than pro...
# 20  OSS is, on average, of LOWER quality than prop...
# 21  OSS is, on average, of LOWER quality than prop...
# 22  The quality of OSS and closed source software ...
# 23                                                NaN
# 24  OSS is, on average, of HIGHER quality than pro...
# 25  OSS is, on average, of HIGHER quality than pro...
# 26  The quality of OSS and closed source software ...
# 27  OSS is, on average, of HIGHER quality than pro...
# 28  OSS is, on average, of HIGHER quality than pro...
# 29  The quality of OSS and closed source software ...
# 30  The quality of OSS and closed source software ...
# 31  OSS is, on average, of HIGHER quality than pro...
# 32  OSS is, on average, of HIGHER quality than pro...
# 33  OSS is, on average, of LOWER quality than prop...
# 34  The quality of OSS and closed source software ...
# 35  OSS is, on average, of HIGHER quality than pro...
# 36  OSS is, on average, of HIGHER quality than pro...
# 37  OSS is, on average, of HIGHER quality than pro...
# 38  OSS is, on average, of HIGHER quality than pro...
# 39  OSS is, on average, of HIGHER quality than pro...
# 40  OSS is, on average, of HIGHER quality than pro...
# 41  The quality of OSS and closed source software ...
# 42  The quality of OSS and closed source software ...
# 43  OSS is, on average, of HIGHER quality than pro...
# 44  OSS is, on average, of HIGHER quality than pro...
# 45  The quality of OSS and closed source software ...
# 46  The quality of OSS and closed source software ...
# 47  OSS is, on average, of LOWER quality than prop...
# 48                                                NaN
# 49  OSS is, on average, of LOWER quality than prop...
# 50  The quality of OSS and closed source software ...
# 51  OSS is, on average, of HIGHER quality than pro...
#
#                                            Employment   Country  \
# 0                  Not employed, but looking for work  Ethiopia
# 1   Independent contractor, freelancer, or self-em...  Ethiopia
# 2   Independent contractor, freelancer, or self-em...  Ethiopia
# 3                                  Employed part-time  Ethiopia
# 4   Independent contractor, freelancer, or self-em...  Ethiopia
# 5                                  Employed full-time  Ethiopia
# 6                                  Employed full-time  Ethiopia
# 7                                  Employed full-time  Ethiopia
# 8                  Not employed, but looking for work  Ethiopia
# 9                                  Employed full-time  Ethiopia
# 10  Independent contractor, freelancer, or self-em...  Ethiopia
# 11  Independent contractor, freelancer, or self-em...  Ethiopia
# 12                                 Employed full-time  Ethiopia
# 13  Independent contractor, freelancer, or self-em...  Ethiopia
# 14                                 Employed full-time  Ethiopia
# 15                                 Employed full-time  Ethiopia
# 16                                 Employed full-time  Ethiopia
# 17                                 Employed full-time  Ethiopia
# 18                                 Employed full-time  Ethiopia
# 19                                 Employed full-time  Ethiopia
# 20                 Not employed, but looking for work  Ethiopia
# 21                                 Employed full-time  Ethiopia
# 22                                 Employed full-time  Ethiopia
# 23                                                NaN  Ethiopia
# 24  Independent contractor, freelancer, or self-em...  Ethiopia
# 25                                            Retired  Ethiopia
# 26                 Not employed, but looking for work  Ethiopia
# 27                                 Employed part-time  Ethiopia
# 28             Not employed, and not looking for work  Ethiopia
# 29  Independent contractor, freelancer, or self-em...  Ethiopia
# 30                 Not employed, but looking for work  Ethiopia
# 31                                 Employed full-time  Ethiopia
# 32                 Not employed, but looking for work  Ethiopia
# 33                                 Employed full-time  Ethiopia
# 34  Independent contractor, freelancer, or self-em...  Ethiopia
# 35                                 Employed full-time  Ethiopia
# 36                                 Employed full-time  Ethiopia
# 37                                 Employed full-time  Ethiopia
# 38                                                NaN  Ethiopia
# 39                                 Employed full-time  Ethiopia
# 40  Independent contractor, freelancer, or self-em...  Ethiopia
# 41  Independent contractor, freelancer, or self-em...  Ethiopia
# 42                                 Employed full-time  Ethiopia
# 43             Not employed, and not looking for work  Ethiopia
# 44  Independent contractor, freelancer, or self-em...  Ethiopia
# 45                                 Employed full-time  Ethiopia
# 46                                 Employed part-time  Ethiopia
# 47                                 Employed full-time  Ethiopia
# 48                                                NaN  Ethiopia
# 49                                 Employed full-time  Ethiopia
# 50                                                NaN  Ethiopia
# 51  Independent contractor, freelancer, or self-em...  Ethiopia
#
#            Student                                            EdLevel  \
# 0   Yes, full-time  Secondary school (e.g. American high school, G...
# 1   Yes, full-time  Secondary school (e.g. American high school, G...
# 2   Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3   Yes, full-time  Some college/university study without earning ...
# 4   Yes, part-time  Some college/university study without earning ...
# 5   Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9   Yes, full-time                                                NaN
# 10  Yes, full-time  Secondary school (e.g. American high school, G...
# 11  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 12              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 13             NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 14              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 16              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 17  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 18              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 19  Yes, full-time             I never completed any formal education
# 20  Yes, full-time  Secondary school (e.g. American high school, G...
# 21  Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 22              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23  Yes, full-time  Secondary school (e.g. American high school, G...
# 24  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 25  Yes, full-time                          Primary/elementary school
# 26  Yes, full-time  Secondary school (e.g. American high school, G...
# 27  Yes, full-time  Secondary school (e.g. American high school, G...
# 28  Yes, full-time  Some college/university study without earning ...
# 29              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 30              No                          Primary/elementary school
# 31              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 32              No  Some college/university study without earning ...
# 33              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 34  Yes, full-time  Secondary school (e.g. American high school, G...
# 35              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 36  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 37              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 38  Yes, full-time                                                NaN
# 39              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 40              No  Secondary school (e.g. American high school, G...
# 41              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 42  Yes, part-time                          Primary/elementary school
# 43  Yes, full-time  Secondary school (e.g. American high school, G...
# 44  Yes, full-time  Some college/university study without earning ...
# 45              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 46              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 47              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 48              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 49  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 50  Yes, full-time          Other doctoral degree (Ph.D, Ed.D., etc.)
# 51              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                        UndergradMajor  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Computer science, computer engineering, or sof...
# 3   Computer science, computer engineering, or sof...
# 4   Another engineering discipline (ex. civil, ele...
# 5   Computer science, computer engineering, or sof...
# 6   Computer science, computer engineering, or sof...
# 7   Computer science, computer engineering, or sof...
# 8   Computer science, computer engineering, or sof...
# 9                       Web development or web design
# 10                                                NaN
# 11  Computer science, computer engineering, or sof...
# 12                          Mathematics or statistics
# 13                           I never declared a major
# 14  Computer science, computer engineering, or sof...
# 15  Computer science, computer engineering, or sof...
# 16  Computer science, computer engineering, or sof...
# 17  Computer science, computer engineering, or sof...
# 18  Computer science, computer engineering, or sof...
# 19                                                NaN
# 20                                                NaN
# 21  Computer science, computer engineering, or sof...
# 22  Computer science, computer engineering, or sof...
# 23                                                NaN
# 24  Computer science, computer engineering, or sof...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Computer science, computer engineering, or sof...
# 29  Computer science, computer engineering, or sof...
# 30                                                NaN
# 31  Computer science, computer engineering, or sof...
# 32  Computer science, computer engineering, or sof...
# 33  Computer science, computer engineering, or sof...
# 34                                                NaN
# 35  Another engineering discipline (ex. civil, ele...
# 36  Computer science, computer engineering, or sof...
# 37  Computer science, computer engineering, or sof...
# 38                                                NaN
# 39  Computer science, computer engineering, or sof...
# 40                                                NaN
# 41  Computer science, computer engineering, or sof...
# 42                                                NaN
# 43                                                NaN
# 44  Computer science, computer engineering, or sof...
# 45  Computer science, computer engineering, or sof...
# 46  Information systems, information technology, o...
# 47  Computer science, computer engineering, or sof...
# 48  Computer science, computer engineering, or sof...
# 49  Computer science, computer engineering, or sof...
# 50  A business discipline (ex. accounting, finance...
# 51  Another engineering discipline (ex. civil, ele...
#
#                                              EduOther  \
# 0                                                 NaN
# 1   Taken an online course in programming or softw...
# 2   Taken an online course in programming or softw...
# 3   Taken an online course in programming or softw...
# 4   Taken an online course in programming or softw...
# 5   Taught yourself a new language, framework, or ...
# 6   Taken an online course in programming or softw...
# 7   Taken an online course in programming or softw...
# 8   Taught yourself a new language, framework, or ...
# 9                                                 NaN
# 10  Taken an online course in programming or softw...
# 11  Taken a part-time in-person course in programm...
# 12  Participated in online coding competitions (e....
# 13                                                NaN
# 14  Taken an online course in programming or softw...
# 15  Taken an online course in programming or softw...
# 16  Taken an online course in programming or softw...
# 17                                                NaN
# 18  Taken an online course in programming or softw...
# 19  Taken an online course in programming or softw...
# 20                                                NaN
# 21  Taken an online course in programming or softw...
# 22  Taken an online course in programming or softw...
# 23                                                NaN
# 24  Taken an online course in programming or softw...
# 25                                                NaN
# 26  Taken a part-time in-person course in programm...
# 27  Taken an online course in programming or softw...
# 28  Participated in a full-time developer training...
# 29  Taken an online course in programming or softw...
# 30                Contributed to open source software
# 31  Taught yourself a new language, framework, or ...
# 32  Taken an online course in programming or softw...
# 33  Taught yourself a new language, framework, or ...
# 34  Taken an online course in programming or softw...
# 35  Taken an online course in programming or softw...
# 36                                                NaN
# 37                                                NaN
# 38  Completed an industry certification program (e...
# 39  Taken an online course in programming or softw...
# 40  Taken an online course in programming or softw...
# 41  Completed an industry certification program (e...
# 42  Taken an online course in programming or softw...
# 43  Taken an online course in programming or softw...
# 44  Taken an online course in programming or softw...
# 45  Taken an online course in programming or softw...
# 46                                                NaN
# 47  Completed an industry certification program (e...
# 48  Taught yourself a new language, framework, or ...
# 49                                                NaN
# 50  Taken an online course in programming or softw...
# 51                                                NaN
#
#                                               OrgSize  \
# 0                                                 NaN
# 1   Just me - I am a freelancer, sole proprietor, ...
# 2   Just me - I am a freelancer, sole proprietor, ...
# 3                                       2-9 employees
# 4                                       2-9 employees
# 5                            10,000 or more employees
# 6                                       2-9 employees
# 7                                       2-9 employees
# 8                                                 NaN
# 9                            10,000 or more employees
# 10                                      2-9 employees
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                      2-9 employees
# 15                                 20 to 99 employees
# 16                                 10 to 19 employees
# 17                                 10 to 19 employees
# 18                                 20 to 99 employees
# 19  Just me - I am a freelancer, sole proprietor, ...
# 20                                                NaN
# 21                                 10 to 19 employees
# 22                               100 to 499 employees
# 23                                                NaN
# 24                                      2-9 employees
# 25                                                NaN
# 26                                                NaN
# 27  Just me - I am a freelancer, sole proprietor, ...
# 28                                                NaN
# 29                                 10 to 19 employees
# 30                                                NaN
# 31                                 20 to 99 employees
# 32                                                NaN
# 33                                                NaN
# 34  Just me - I am a freelancer, sole proprietor, ...
# 35                                 20 to 99 employees
# 36                           1,000 to 4,999 employees
# 37                                 10 to 19 employees
# 38                                                NaN
# 39                               100 to 499 employees
# 40  Just me - I am a freelancer, sole proprietor, ...
# 41  Just me - I am a freelancer, sole proprietor, ...
# 42                                                NaN
# 43                                                NaN
# 44  Just me - I am a freelancer, sole proprietor, ...
# 45                                      2-9 employees
# 46                                 20 to 99 employees
# 47                                 20 to 99 employees
# 48                                                NaN
# 49                                 20 to 99 employees
# 50                                                NaN
# 51                                      2-9 employees
#
#                                               DevType         YearsCode  \
# 0                                             Student  Less than 1 year
# 1   Developer, back-end;Developer, desktop or ente...                 6
# 2   Data scientist or machine learning specialist;...                 9
# 3   Data scientist or machine learning specialist;...                 5
# 4   Developer, back-end;Developer, embedded applic...                 5
# 5                                 Developer, back-end                 4
# 6              Developer, front-end;Developer, mobile                 6
# 7   Data or business analyst;Developer, full-stack...                 5
# 8   Designer;Developer, back-end;Developer, deskto...                 2
# 9   Academic researcher;Database administrator;Edu...                 6
# 10  Database administrator;Designer;Developer, bac...                 9
# 11  Developer, desktop or enterprise applications;...                 4
# 12                                   Designer;Student                 5
# 13  Designer;Developer, back-end;Developer, deskto...                13
# 14                      Developer, full-stack;Student                 6
# 15  Developer, back-end;Developer, embedded applic...                 6
# 16                                  Developer, mobile                 5
# 17  Database administrator;Developer, back-end;Dev...                 7
# 18                                  DevOps specialist                 9
# 19                                Academic researcher               NaN
# 20  Developer, embedded applications or devices;De...                 4
# 21  Database administrator;Developer, back-end;Dev...                 5
# 22  Designer;Developer, front-end;Developer, mobil...                 5
# 23                                                NaN                 5
# 24  Developer, embedded applications or devices;De...                12
# 25                                                NaN                 4
# 26  Developer, embedded applications or devices;En...                 5
# 27  Developer, back-end;Developer, front-end;Devel...                 5
# 28                                                NaN                 3
# 29  Designer;Developer, back-end;Developer, front-...                10
# 30        Developer, embedded applications or devices                 2
# 31                              Developer, full-stack                10
# 32                          Developer, mobile;Student               NaN
# 33  Designer;Developer, desktop or enterprise appl...                 3
# 34  Designer;Developer, back-end;Developer, front-...  Less than 1 year
# 35  Developer, back-end;Developer, embedded applic...                10
# 36                              Developer, full-stack                 7
# 37  Designer;Developer, desktop or enterprise appl...                 4
# 38                                                NaN                17
# 39                              Developer, full-stack                 5
# 40  Designer;Developer, back-end;Developer, deskto...                 3
# 41          Developer, back-end;Developer, full-stack                11
# 42  Academic researcher;Data or business analyst;D...  Less than 1 year
# 43                                                NaN                 4
# 44                                                NaN                 4
# 45  Developer, back-end;Developer, full-stack;Deve...                 5
# 46  Developer, front-end;Educator;System administr...               NaN
# 47          Developer, back-end;Developer, full-stack                 8
# 48                                                NaN                 9
# 49           Developer, back-end;Developer, front-end                 5
# 50                                                NaN                 1
# 51                Designer;Engineer, site reliability                 5
#
#               Age1stCode      YearsCodePro  \
# 0                     18               NaN
# 1                     14  Less than 1 year
# 2                     13                 3
# 3                     18                 1
# 4                     13                 2
# 5                     19  Less than 1 year
# 6                     17                 2
# 7                     17                 2
# 8                     20               NaN
# 9                     18                 3
# 10                    12                 1
# 11                    17               NaN
# 12                    15  Less than 1 year
# 13                    16                10
# 14                    18                 2
# 15                    19                 2
# 16                    17                 1
# 17                    21                 5
# 18                    20                 4
# 19                   NaN               NaN
# 20                    17               NaN
# 21                    20                 5
# 22                    21                 2
# 23                    14               NaN
# 24                    20                 8
# 25                    19               NaN
# 26                    14               NaN
# 27                    14                 2
# 28                    19               NaN
# 29                    16                 6
# 30                     5                 3
# 31                    16                 7
# 32                   NaN               NaN
# 33                    17                 2
# 34                    20  Less than 1 year
# 35                    18                 4
# 36                    20                 2
# 37                    25                 2
# 38                     6               NaN
# 39                    15                 4
# 40                    13               NaN
# 41                    18                 8
# 42  Younger than 5 years               NaN
# 43                    16               NaN
# 44                    18                 4
# 45                    19  Less than 1 year
# 46                   NaN               NaN
# 47                    18                 3
# 48                    14               NaN
# 49                    19                 1
# 50                    15                 3
# 51                    34                 7
#
#                              CareerSat                              JobSat  \
# 0                                  NaN                                 NaN
# 1                   Slightly satisfied                      Very satisfied
# 2                   Slightly satisfied                      Very satisfied
# 3   Neither satisfied nor dissatisfied  Neither satisfied nor dissatisfied
# 4                   Slightly satisfied                  Slightly satisfied
# 5                Slightly dissatisfied                   Very dissatisfied
# 6                       Very satisfied                  Slightly satisfied
# 7                   Slightly satisfied                  Slightly satisfied
# 8                                  NaN                                 NaN
# 9                    Very dissatisfied                      Very satisfied
# 10                  Slightly satisfied  Neither satisfied nor dissatisfied
# 11                                 NaN                                 NaN
# 12  Neither satisfied nor dissatisfied                  Slightly satisfied
# 13                      Very satisfied                      Very satisfied
# 14                      Very satisfied               Slightly dissatisfied
# 15                      Very satisfied                  Slightly satisfied
# 16                      Very satisfied                      Very satisfied
# 17                   Very dissatisfied                   Very dissatisfied
# 18               Slightly dissatisfied               Slightly dissatisfied
# 19                   Very dissatisfied                   Very dissatisfied
# 20                                 NaN                                 NaN
# 21                      Very satisfied  Neither satisfied nor dissatisfied
# 22               Slightly dissatisfied               Slightly dissatisfied
# 23                                 NaN                                 NaN
# 24                  Slightly satisfied                  Slightly satisfied
# 25                                 NaN                                 NaN
# 26                                 NaN                                 NaN
# 27                      Very satisfied                      Very satisfied
# 28                                 NaN                                 NaN
# 29                      Very satisfied                      Very satisfied
# 30                   Very dissatisfied                                 NaN
# 31                      Very satisfied                  Slightly satisfied
# 32                                 NaN                                 NaN
# 33                  Slightly satisfied                      Very satisfied
# 34                      Very satisfied                      Very satisfied
# 35  Neither satisfied nor dissatisfied               Slightly dissatisfied
# 36                                 NaN                                 NaN
# 37  Neither satisfied nor dissatisfied                  Slightly satisfied
# 38                                 NaN                                 NaN
# 39  Neither satisfied nor dissatisfied  Neither satisfied nor dissatisfied
# 40                                 NaN                                 NaN
# 41                  Slightly satisfied                  Slightly satisfied
# 42                                 NaN                                 NaN
# 43                                 NaN                                 NaN
# 44                      Very satisfied                  Slightly satisfied
# 45                  Slightly satisfied                  Slightly satisfied
# 46                  Slightly satisfied                  Slightly satisfied
# 47               Slightly dissatisfied                  Slightly satisfied
# 48                                 NaN                                 NaN
# 49                      Very satisfied                      Very satisfied
# 50                                 NaN                                 NaN
# 51                                 NaN                                 NaN
#
#                 MgrIdiot  MgrMoney   MgrWant  \
# 0                    NaN       NaN       NaN
# 1                    NaN       NaN       NaN
# 2                    NaN       NaN       NaN
# 3     Somewhat confident        No       Yes
# 4                    NaN       NaN       NaN
# 5     Somewhat confident        No       Yes
# 6         Very confident  Not sure       Yes
# 7   Not at all confident       Yes       Yes
# 8                    NaN       NaN       NaN
# 9         Very confident       Yes       Yes
# 10                   NaN       NaN       NaN
# 11                   NaN       NaN       NaN
# 12    Somewhat confident       Yes  Not sure
# 13                   NaN       NaN       NaN
# 14  Not at all confident        No  Not sure
# 15        Very confident        No        No
# 16        Very confident        No        No
# 17        Very confident       Yes       Yes
# 18    Somewhat confident        No       Yes
# 19        Very confident       Yes       Yes
# 20                   NaN       NaN       NaN
# 21    Somewhat confident        No        No
# 22        Very confident       Yes       Yes
# 23                   NaN       NaN       NaN
# 24                   NaN       NaN       NaN
# 25                   NaN       NaN       NaN
# 26                   NaN       NaN       NaN
# 27        Very confident        No        No
# 28                   NaN       NaN       NaN
# 29                   NaN       NaN       NaN
# 30                   NaN       NaN       NaN
# 31    Somewhat confident        No  Not sure
# 32                   NaN       NaN       NaN
# 33        Very confident  Not sure       Yes
# 34                   NaN       NaN       NaN
# 35    Somewhat confident        No        No
# 36    Somewhat confident  Not sure       Yes
# 37  Not at all confident        No  Not sure
# 38                   NaN       NaN       NaN
# 39    Somewhat confident  Not sure  Not sure
# 40                   NaN       NaN       NaN
# 41                   NaN       NaN       NaN
# 42                   NaN       NaN       NaN
# 43                   NaN       NaN       NaN
# 44                   NaN       NaN       NaN
# 45  Not at all confident       Yes       Yes
# 46        Very confident       Yes       Yes
# 47        Very confident        No       Yes
# 48                   NaN       NaN       NaN
# 49        Very confident        No        No
# 50                   NaN       NaN       NaN
# 51                   NaN       NaN       NaN
#
#                                               JobSeek  \
# 0   I’m not actively looking, but I am open to new...
# 1   I’m not actively looking, but I am open to new...
# 2                     I am actively looking for a job
# 3   I’m not actively looking, but I am open to new...
# 4   I’m not actively looking, but I am open to new...
# 5                     I am actively looking for a job
# 6   I’m not actively looking, but I am open to new...
# 7   I’m not actively looking, but I am open to new...
# 8   I’m not actively looking, but I am open to new...
# 9                     I am actively looking for a job
# 10  I’m not actively looking, but I am open to new...
# 11  I’m not actively looking, but I am open to new...
# 12  I’m not actively looking, but I am open to new...
# 13       I am not interested in new job opportunities
# 14                    I am actively looking for a job
# 15  I’m not actively looking, but I am open to new...
# 16       I am not interested in new job opportunities
# 17  I’m not actively looking, but I am open to new...
# 18                    I am actively looking for a job
# 19                    I am actively looking for a job
# 20  I’m not actively looking, but I am open to new...
# 21  I’m not actively looking, but I am open to new...
# 22                    I am actively looking for a job
# 23  I’m not actively looking, but I am open to new...
# 24                    I am actively looking for a job
# 25                                                NaN
# 26  I’m not actively looking, but I am open to new...
# 27  I’m not actively looking, but I am open to new...
# 28                                                NaN
# 29  I’m not actively looking, but I am open to new...
# 30  I’m not actively looking, but I am open to new...
# 31  I’m not actively looking, but I am open to new...
# 32  I’m not actively looking, but I am open to new...
# 33  I’m not actively looking, but I am open to new...
# 34  I’m not actively looking, but I am open to new...
# 35  I’m not actively looking, but I am open to new...
# 36                                                NaN
# 37                    I am actively looking for a job
# 38                    I am actively looking for a job
# 39                    I am actively looking for a job
# 40                                                NaN
# 41                    I am actively looking for a job
# 42                    I am actively looking for a job
# 43                                                NaN
# 44  I’m not actively looking, but I am open to new...
# 45  I’m not actively looking, but I am open to new...
# 46  I’m not actively looking, but I am open to new...
# 47  I’m not actively looking, but I am open to new...
# 48                                                NaN
# 49  I’m not actively looking, but I am open to new...
# 50                                                NaN
# 51                                                NaN
#
#                                          LastHireDate  \
# 0                                I've never had a job
# 1                                Less than a year ago
# 2                                Less than a year ago
# 3                                Less than a year ago
# 4   NA - I am an independent contractor or self em...
# 5                                       1-2 years ago
# 6                                Less than a year ago
# 7                                Less than a year ago
# 8                                Less than a year ago
# 9                                       1-2 years ago
# 10                                      1-2 years ago
# 11  NA - I am an independent contractor or self em...
# 12                               Less than a year ago
# 13  NA - I am an independent contractor or self em...
# 14                                      1-2 years ago
# 15                               Less than a year ago
# 16                                      1-2 years ago
# 17                                      3-4 years ago
# 18                                      1-2 years ago
# 19                               Less than a year ago
# 20                               I've never had a job
# 21                              More than 4 years ago
# 22                                      1-2 years ago
# 23                               I've never had a job
# 24                               Less than a year ago
# 25                                                NaN
# 26  NA - I am an independent contractor or self em...
# 27                               Less than a year ago
# 28                                                NaN
# 29                                      1-2 years ago
# 30                                      3-4 years ago
# 31                               Less than a year ago
# 32                                                NaN
# 33                                      1-2 years ago
# 34  NA - I am an independent contractor or self em...
# 35                               Less than a year ago
# 36                                                NaN
# 37                                      1-2 years ago
# 38                                      1-2 years ago
# 39                                      1-2 years ago
# 40                                                NaN
# 41  NA - I am an independent contractor or self em...
# 42                               I've never had a job
# 43                                                NaN
# 44                                      1-2 years ago
# 45                               Less than a year ago
# 46                                      3-4 years ago
# 47                               Less than a year ago
# 48                                                NaN
# 49                                      1-2 years ago
# 50                                                NaN
# 51                                                NaN
#
#                                               LastInt FizzBuzz  \
# 0                                                 NaN      NaN
# 1   Write any code;Interview with people in peer r...       No
# 2   Write any code;Write code by hand (e.g., on a ...      Yes
# 3   Write any code;Complete a take-home project;In...       No
# 4                                                 NaN      NaN
# 5   Write any code;Interview with people in senior...       No
# 6   Write any code;Interview with people in senior...       No
# 7   Interview with people in senior / management r...       No
# 8                                                 NaN      NaN
# 9   Write any code;Write code by hand (e.g., on a ...       No
# 10  Write any code;Interview with people in senior...       No
# 11                                                NaN      NaN
# 12  Solve a brain-teaser style puzzle;Interview wi...       No
# 13                                                NaN      NaN
# 14                       Complete a take-home project       No
# 15  Write code by hand (e.g., on a whiteboard);Int...       No
# 16  Interview with people in senior / management r...       No
# 17                       Complete a take-home project      NaN
# 18  Write code by hand (e.g., on a whiteboard);Int...       No
# 19                                     Write any code      Yes
# 20                                                NaN      NaN
# 21        Write any code;Complete a take-home project       No
# 22         Write code by hand (e.g., on a whiteboard)       No
# 23                                                NaN      NaN
# 24                Interview with people in peer roles       No
# 25                                                NaN      NaN
# 26                                                NaN      NaN
# 27  Write any code;Complete a take-home project;In...      Yes
# 28                                                NaN      NaN
# 29  Complete a take-home project;Interview with pe...       No
# 30         Write code by hand (e.g., on a whiteboard)       No
# 31  Write any code;Write code by hand (e.g., on a ...       No
# 32                                                NaN      NaN
# 33  Interview with people in peer roles;Interview ...      NaN
# 34                                                NaN       No
# 35  Interview with people in senior / management r...       No
# 36                                                NaN      NaN
# 37                  Solve a brain-teaser style puzzle       No
# 38                                                NaN      NaN
# 39   Write any code;Solve a brain-teaser style puzzle       No
# 40                                                NaN      NaN
# ...
# 7               A lot more welcome now than last year
# 8             Just as welcome now as I felt last year
# 9            Somewhat more welcome now than last year
# 10           Somewhat more welcome now than last year
# 11           Somewhat more welcome now than last year
# 12           Somewhat more welcome now than last year
# 13            Just as welcome now as I felt last year
# 14            Just as welcome now as I felt last year
# 15              A lot more welcome now than last year
# 16            Just as welcome now as I felt last year
# 17                                                NaN
# 18            Just as welcome now as I felt last year
# 19              A lot less welcome now than last year
# 20           Somewhat less welcome now than last year
# 21            Just as welcome now as I felt last year
# 22            Just as welcome now as I felt last year
# 23              A lot more welcome now than last year
# 24            Just as welcome now as I felt last year
# 25           Somewhat less welcome now than last year
# 26            Just as welcome now as I felt last year
# 27              A lot more welcome now than last year
# 28           Somewhat more welcome now than last year
# 29            Just as welcome now as I felt last year
# 30              A lot more welcome now than last year
# 31            Just as welcome now as I felt last year
# 32                                                NaN
# 33  Not applicable - I did not use Stack Overflow ...
# 34            Just as welcome now as I felt last year
# 35            Just as welcome now as I felt last year
# 36           Somewhat more welcome now than last year
# 37              A lot more welcome now than last year
# 38            Just as welcome now as I felt last year
# 39            Just as welcome now as I felt last year
# 40            Just as welcome now as I felt last year
# 41              A lot more welcome now than last year
# 42              A lot less welcome now than last year
# 43            Just as welcome now as I felt last year
# 44           Somewhat more welcome now than last year
# 45           Somewhat less welcome now than last year
# 46              A lot more welcome now than last year
# 47            Just as welcome now as I felt last year
# 48            Just as welcome now as I felt last year
# 49              A lot more welcome now than last year
# 50              A lot less welcome now than last year
# 51  Not applicable - I did not use Stack Overflow ...
#
#                                          SONewContent   Age  \
# 0                                                 NaN   NaN
# 1                                                 NaN  20.0
# 2   Tech articles written by other developers;Indu...  21.0
# 3   Tech articles written by other developers;Indu...  23.0
# 4   Tech articles written by other developers;Indu...  22.0
# 5   Tech articles written by other developers;Indu...  25.0
# 6   Tech articles written by other developers;Indu...  24.0
# 7   Tech meetups or events in your area;Courses on...  23.0
# 8           Tech articles written by other developers  25.0
# 9   Tech articles written by other developers;Indu...  24.0
# 10  Tech articles written by other developers;Indu...  21.0
# 11  Tech articles written by other developers;Tech...  21.0
# 12  Tech articles written by other developers;Indu...  25.0
# 13          Tech articles written by other developers   NaN
# 14  Tech articles written by other developers;Cour...   NaN
# 15  Tech articles written by other developers;Tech...  25.0
# 16  Tech articles written by other developers;Indu...  22.0
# 17                                                NaN   NaN
# 18          Tech articles written by other developers  32.0
# 19          Tech articles written by other developers  22.0
# 20  Tech articles written by other developers;Indu...  21.0
# 21          Tech articles written by other developers  30.0
# 22  Tech articles written by other developers;Indu...  27.0
# 23  Tech articles written by other developers;Cour...  19.0
# 24                                                NaN  35.0
# 25          Tech articles written by other developers  23.0
# 26  Tech articles written by other developers;Indu...  23.0
# 27  Tech articles written by other developers;Tech...  20.0
# 28  Tech articles written by other developers;Indu...  21.0
# 29  Tech articles written by other developers;Indu...  30.0
# 30                Tech meetups or events in your area  36.0
# 31                                                NaN   NaN
# 32  Tech articles written by other developers;Indu...  30.0
# 33  Tech articles written by other developers;Indu...   NaN
# 34  Industry news about technologies you're intere...  20.0
# 35  Tech articles written by other developers;Indu...  28.0
# 36  Industry news about technologies you're intere...  25.0
# 37  Tech articles written by other developers;Indu...  28.0
# 38       Courses on technologies you're interested in  29.0
# 39  Tech articles written by other developers;Indu...  25.0
# 40          Tech articles written by other developers  17.0
# 41  Industry news about technologies you're intere...  30.0
# 42  Tech articles written by other developers;Indu...   NaN
# 43                                                NaN   NaN
# 44                                                NaN  22.0
# 45  Industry news about technologies you're intere...   NaN
# 46  Tech articles written by other developers;Indu...   NaN
# 47                                                NaN  24.0
# 48                                                NaN  25.0
# 49                                                NaN  24.0
# 50          Tech articles written by other developers  23.0
# 51  Tech articles written by other developers;Indu...  38.0
#
#                                                Gender Trans  \
# 0                                                 Man    No
# 1                                                 Man    No
# 2                                                 Man    No
# 3                                                 Man    No
# 4                                                 Man    No
# 5                                               Woman    No
# 6                                               Woman    No
# 7                                                 Man    No
# 8                                                 Man    No
# 9                                                 Man    No
# 10                                                Man    No
# 11                                                Man    No
# 12                                                Man    No
# 13                                                NaN   NaN
# 14                                                Man    No
# 15                                                Man    No
# 16                                                Man   NaN
# 17                                                NaN   NaN
# 18                                                Man    No
# 19                                              Woman   Yes
# 20  Non-binary, genderqueer, or gender non-conforming   Yes
# 21                                                Man    No
# 22                                                Man    No
# 23                                                Man    No
# 24                                                Man    No
# 25                                                Man    No
# 26                                              Woman    No
# 27                                                Man    No
# 28                                                Man    No
# 29                                                Man    No
# 30                                                Man    No
# 31                                                Man    No
# 32                                                Man    No
# 33                                                NaN   NaN
# 34                                                Man    No
# 35                                                Man    No
# 36                                                Man    No
# 37                                                Man    No
# 38                                                Man   NaN
# 39                                                Man    No
# 40                                                Man    No
# 41                                                Man    No
# 42                                                NaN    No
# 43                                                Man    No
# 44                                                Man    No
# 45                                                Man    No
# 46                                                Man   NaN
# 47                                                Man    No
# 48                                                Man    No
# 49                                                Man   NaN
# 50                                                Man    No
# 51                                                Man   NaN
#
#                   Sexuality                    Ethnicity Dependents  \
# 0   Straight / Heterosexual  Black or of African descent        NaN
# 1   Straight / Heterosexual  Black or of African descent         No
# 2   Straight / Heterosexual  Black or of African descent         No
# 3   Straight / Heterosexual  Black or of African descent         No
# 4   Straight / Heterosexual  Black or of African descent         No
# 5   Straight / Heterosexual  Black or of African descent        Yes
# 6   Straight / Heterosexual  Black or of African descent         No
# 7   Straight / Heterosexual                          NaN        Yes
# 8   Straight / Heterosexual  Black or of African descent         No
# 9                       NaN  Black or of African descent        Yes
# 10  Straight / Heterosexual  Black or of African descent         No
# 11  Straight / Heterosexual  Black or of African descent         No
# 12  Straight / Heterosexual  Black or of African descent         No
# 13                      NaN                          NaN        NaN
# 14  Straight / Heterosexual  Black or of African descent         No
# 15  Straight / Heterosexual  Black or of African descent         No
# 16                      NaN  Black or of African descent        NaN
# 17                      NaN                          NaN        NaN
# 18  Straight / Heterosexual  Black or of African descent         No
# 19                 Bisexual  Black or of African descent        Yes
# 20                      NaN                          NaN         No
# 21  Straight / Heterosexual  Black or of African descent         No
# 22  Straight / Heterosexual  Black or of African descent         No
# 23                      NaN                          NaN         No
# 24  Straight / Heterosexual  Black or of African descent        Yes
# 25                      NaN  Black or of African descent         No
# 26  Straight / Heterosexual                          NaN         No
# 27  Straight / Heterosexual  Black or of African descent         No
# 28  Straight / Heterosexual  Black or of African descent         No
# 29  Straight / Heterosexual  Black or of African descent        Yes
# 30                 Bisexual  Black or of African descent        Yes
# 31  Straight / Heterosexual  Black or of African descent         No
# 32                      NaN                          NaN         No
# 33                      NaN                          NaN        NaN
# 34  Straight / Heterosexual  Black or of African descent         No
# 35  Straight / Heterosexual  Black or of African descent        NaN
# 36                      NaN  Black or of African descent        NaN
# 37                      NaN  Black or of African descent        Yes
# 38                      NaN  Black or of African descent        Yes
# 39  Straight / Heterosexual  Black or of African descent         No
# 40  Straight / Heterosexual  Black or of African descent        NaN
# 41  Straight / Heterosexual                          NaN        Yes
# 42                      NaN                          NaN        Yes
# 43  Straight / Heterosexual  Black or of African descent         No
# 44  Straight / Heterosexual  Black or of African descent         No
# 45  Straight / Heterosexual  Black or of African descent         No
# 46  Straight / Heterosexual  Black or of African descent         No
# 47  Straight / Heterosexual  Black or of African descent         No
# 48  Straight / Heterosexual  Black or of African descent         No
# 49  Straight / Heterosexual  Black or of African descent        Yes
# 50                      NaN  Black or of African descent         No
# 51                      NaN                          NaN        Yes
#
#              SurveyLength                  SurveyEase
# 0                Too long                        Easy
# 1   Appropriate in length  Neither easy nor difficult
# 2   Appropriate in length                        Easy
# 3   Appropriate in length                        Easy
# 4                Too long                        Easy
# 5                Too long                        Easy
# 6                Too long                        Easy
# 7   Appropriate in length                        Easy
# 8   Appropriate in length  Neither easy nor difficult
# 9   Appropriate in length  Neither easy nor difficult
# 10               Too long  Neither easy nor difficult
# 11  Appropriate in length  Neither easy nor difficult
# 12               Too long  Neither easy nor difficult
# 13               Too long                        Easy
# 14  Appropriate in length  Neither easy nor difficult
# 15               Too long                        Easy
# 16               Too long  Neither easy nor difficult
# 17                    NaN                         NaN
# 18  Appropriate in length  Neither easy nor difficult
# 19              Too short                        Easy
# 20               Too long  Neither easy nor difficult
# 21  Appropriate in length                        Easy
# 22               Too long                        Easy
# 23               Too long  Neither easy nor difficult
# 24               Too long                        Easy
# 25  Appropriate in length                        Easy
# 26               Too long  Neither easy nor difficult
# 27  Appropriate in length                        Easy
# 28               Too long                        Easy
# 29  Appropriate in length  Neither easy nor difficult
# 30              Too short                        Easy
# 31               Too long                   Difficult
# 32  Appropriate in length                   Difficult
# 33  Appropriate in length  Neither easy nor difficult
# 34  Appropriate in length                        Easy
# 35               Too long                        Easy
# 36  Appropriate in length  Neither easy nor difficult
# 37               Too long                        Easy
# 38               Too long                        Easy
# 39               Too long                        Easy
# 40  Appropriate in length                        Easy
# 41  Appropriate in length                        Easy
# 42  Appropriate in length                        Easy
# 43               Too long                        Easy
# 44               Too long                        Easy
# 45               Too long                        Easy
# 46               Too long                         NaN
# 47  Appropriate in length                        Easy
# 48  Appropriate in length                        Easy
# 49               Too long                   Difficult
# 50               Too long                         NaN
# 51  Appropriate in length                         NaN

# %%
ethiopia.to_csv('Ethiopia')

# %%
ethiopia.to_excel('Ethiopiaa2.xlsx')
