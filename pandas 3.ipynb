# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'Column')

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
# lets try to sort one of the dataframes column that is one series

df['Country'].sort_values()
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
#             ...
# 88062            NaN
# 88076            NaN
# 88601            NaN
# 88802            NaN
# 88816            NaN
# Name: Country, Length: 88883, dtype: object

# %%
df['Country'].sort_values()
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
#             ...
# 88062            NaN
# 88076            NaN
# 88601            NaN
# 88802            NaN
# 88816            NaN
# Name: Country, Length: 88883, dtype: object

# %%
df.head(2)       # just no change to the df since pick a series and sort it and that is all
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
# but to sort the data frames contry column

df.sort_values(by='Country', inplace=True, ignore_index=True)

# %%
df
# Out:
#                            MainBranch Hobbyist              OpenSourcer  \
# 0      I am a developer by profession      Yes  Less than once per year
# 1      I am a developer by profession      Yes                    Never
# 2      I am a developer by profession       No  Less than once per year
# 3      I am a developer by profession       No  Less than once per year
# 4                                 NaN      Yes  Less than once per year
# ...                               ...      ...                      ...
# 88878                             NaN       No                    Never
# 88879                             NaN       No                    Never
# 88880                             NaN       No                    Never
# 88881                             NaN       No                    Never
# 88882                             NaN       No                    Never
#
#                                               OpenSource  \
# ...

# %%
df[['Country', 'ConvertedComp']].head(50)       # just pass a list of columns to be displayed
# Out:
#         Country  ConvertedComp
# 0   Afghanistan        19152.0
# 1   Afghanistan      1000000.0
# 2   Afghanistan            NaN
# 3   Afghanistan            NaN
# 4   Afghanistan            NaN
# 5   Afghanistan            NaN
# 6   Afghanistan            NaN
# 7   Afghanistan            NaN
# 8   Afghanistan            NaN
# 9   Afghanistan         4464.0
# 10  Afghanistan         3996.0
# 11  Afghanistan            NaN
# 12  Afghanistan            NaN
# 13  Afghanistan            NaN
# 14  Afghanistan            NaN
# 15  Afghanistan            NaN
# 16  Afghanistan            NaN
# 17  Afghanistan            0.0
# 18  Afghanistan            0.0
# 19  Afghanistan            NaN
# 20  Afghanistan            NaN
# 21  Afghanistan            NaN
# 22  Afghanistan        14364.0
# 23  Afghanistan            NaN
# 24  Afghanistan            NaN
# 25  Afghanistan            NaN
# 26  Afghanistan            NaN
# 27  Afghanistan            NaN
# 28  Afghanistan            NaN
# ...

# %%
# sort by country and then by salary

df[['Country', 'ConvertedComp']].sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False]).head(50)
# Out:
#          Country  ConvertedComp
# 1    Afghanistan      1000000.0
# 43   Afghanistan       153216.0
# 0    Afghanistan        19152.0
# 41   Afghanistan        17556.0
# 22   Afghanistan        14364.0
# 32   Afghanistan         7980.0
# 9    Afghanistan         4464.0
# 10   Afghanistan         3996.0
# 33   Afghanistan         1596.0
# 38   Afghanistan         1116.0
# 17   Afghanistan            0.0
# 18   Afghanistan            0.0
# 2    Afghanistan            NaN
# 3    Afghanistan            NaN
# 4    Afghanistan            NaN
# 5    Afghanistan            NaN
# 6    Afghanistan            NaN
# 7    Afghanistan            NaN
# 8    Afghanistan            NaN
# 11   Afghanistan            NaN
# 12   Afghanistan            NaN
# 13   Afghanistan            NaN
# 14   Afghanistan            NaN
# 15   Afghanistan            NaN
# 16   Afghanistan            NaN
# 19   Afghanistan            NaN
# 20   Afghanistan            NaN
# 21   Afghanistan            NaN
# ...

# %%
df[['Country', 'ConvertedComp']].sort_values(by='ConvertedComp', ascending=False).head(5)
# Out:
#              Country  ConvertedComp
# 82319  United States      2000000.0
# 68324  United States      2000000.0
# 85879  United States      2000000.0
# 72124  United States      2000000.0
# 85904  United States      2000000.0

# %%
# to get the top ten largest value from the series

df['ConvertedComp'].nlargest(10)
# Out:
# 9500     2000000.0
# 22195    2000000.0
# 29307    2000000.0
# 32179    2000000.0
# 33819    2000000.0
# 41011    2000000.0
# 42333    2000000.0
# 46870    2000000.0
# 53005    2000000.0
# 58230    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
# also wanna see other columns just apply it on the dataframe

df.nlargest(10, 'ConvertedComp')
# Out:
#                                               MainBranch Hobbyist  \
# 9500                      I am a developer by profession      Yes
# 22195                     I am a developer by profession      Yes
# 29307                     I am a developer by profession      Yes
# 32179                     I am a developer by profession      Yes
# 33819  I am not primarily a developer, but I write co...       No
# 41011                     I am a developer by profession      Yes
# 42333                     I am a developer by profession      Yes
# 46870                     I am a developer by profession      Yes
# 53005                     I am a developer by profession      Yes
# 58230                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 9500                             Less than once per year
# 22195                            Less than once per year
# 29307                                              Never
# ...

# %%
# the smallest will will be found

df.nsmallest(10, 'ConvertedComp')
# Out:
#                                              MainBranch Hobbyist  \
# 17                       I am a developer by profession      Yes
# 18                       I am a developer by profession       No
# 240                      I am a developer by profession      Yes
# 873                      I am a developer by profession      Yes
# 1027                     I am a developer by profession      Yes
# 2553                     I am a developer by profession       No
# 3315  I am not primarily a developer, but I write co...      Yes
# 4001  I am not primarily a developer, but I write co...      Yes
# 5324                     I am a developer by profession      Yes
# 6138                     I am a developer by profession      Yes
#
#                                             OpenSourcer  \
# 17    Less than once a month but more than once per ...
# 18    Less than once a month but more than once per ...
# 240                                               Never
# ...
