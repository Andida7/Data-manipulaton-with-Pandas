# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('countries.csv')

# %%
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# lets compare the population growth for china and america
cntry_grp = df.groupby('country')

# %%
df['country'].value_counts()['United States']
# Out:
# 12

# %%
us = cntry_grp.get_group('United States').reset_index(drop=True)
us
# Out:
#           country  year  population
# 0   United States  1952   157553000
# 1   United States  1957   171984000
# 2   United States  1962   186538000
# 3   United States  1967   198712000
# 4   United States  1972   209896000
# 5   United States  1977   220239000
# 6   United States  1982   232187835
# 7   United States  1987   242803533
# 8   United States  1992   256894189
# 9   United States  1997   272911760
# 10  United States  2002   287675526
# 11  United States  2007   301139947

# %%
plt.plot(us.year, us.population/10**9, color = 'b',linestyle = '-', linewidth = 2, label = 'US')
plt.style.use('ggplot')

plt.xlabel('Year')
plt.ylabel('Population in billions')
plt.title('US population growth over 12 years')
plt.legend()

plt.tight_layout()
plt.show()

# %%
china = cntry_grp.get_group('China').reset_index(drop=True)
china
# Out:
#    country  year  population
# 0    China  1952   556263527
# 1    China  1957   637408000
# 2    China  1962   665770000
# 3    China  1967   754550000
# 4    China  1972   862030000
# 5    China  1977   943455000
# 6    China  1982  1000281000
# 7    China  1987  1084035000
# 8    China  1992  1164970000
# 9    China  1997  1230075000
# 10   China  2002  1280400000
# 11   China  2007  1318683096

# %%
# lets plot a graph for china

plt.plot(china.year, china.population/10**9, color = 'k',linestyle = '--', linewidth = 2, label = 'China')

plt.style.use('ggplot')

plt.xlabel('Year')
plt.ylabel('Population in billions')
plt.legend()

plt.title("China's population growth over 12 years")

plt.tight_layout()
plt.show()

# %%
# lets draw them together
plt.plot(china.year, china.population/10**9, color = 'k',linestyle = '--', linewidth = 2, label = 'China')
plt.plot(us.year, us.population/10**9, color = 'b',linestyle = '-', linewidth = 2, label = 'US')

plt.style.use('ggplot')

plt.xlabel('Year')
plt.ylabel('Population in billions')
plt.legend()

plt.title("population growth over 12 years")

plt.tight_layout()
plt.show()

# %%
china.rename(columns={'population':'population_of_china'}, inplace = True)
us.rename(columns={'population':'population_of_US'}, inplace = True)

# %%
china.drop(columns=['country'], inplace=True)
china
# Out:
#     year  population_of_china
# 0   1952            556263527
# 1   1957            637408000
# 2   1962            665770000
# 3   1967            754550000
# 4   1972            862030000
# 5   1977            943455000
# 6   1982           1000281000
# 7   1987           1084035000
# 8   1992           1164970000
# 9   1997           1230075000
# 10  2002           1280400000
# 11  2007           1318683096

# %%
us.drop(columns=['country'], inplace=True)
us
# Out:
#     year  population_of_US
# 0   1952         157553000
# 1   1957         171984000
# 2   1962         186538000
# 3   1967         198712000
# 4   1972         209896000
# 5   1977         220239000
# 6   1982         232187835
# 7   1987         242803533
# 8   1992         256894189
# 9   1997         272911760
# 10  2002         287675526
# 11  2007         301139947

# %%
us['population_of_china'] = china['population_of_china']

# %%
population = us
population
# Out:
#     year  population_of_US  population_of_china
# 0   1952         157553000            556263527
# 1   1957         171984000            637408000
# 2   1962         186538000            665770000
# 3   1967         198712000            754550000
# 4   1972         209896000            862030000
# 5   1977         220239000            943455000
# 6   1982         232187835           1000281000
# 7   1987         242803533           1084035000
# 8   1992         256894189           1164970000
# 9   1997         272911760           1230075000
# 10  2002         287675526           1280400000
# 11  2007         301139947           1318683096

# %%
# lets draw them together
plt.plot(population.year
         , population.population_of_china/10**6, color = 'k',linestyle = '--', linewidth = 2, label = 'population_of_china')

plt.plot(population.year, population.population_of_US/10**6, color = 'b',linestyle = '-'
         , linewidth = 2, label = 'population_of_US')

plt.style.use('ggplot')

plt.xlabel('Year')
plt.ylabel('Population in millions')
plt.legend()

plt.title("population growth over 12 years")

plt.tight_layout()
plt.show()

# %%
#coming...
